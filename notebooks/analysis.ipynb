# %% [markdown]
# # MobileLens-2025
#
# ### *Smatphone Pricing & Specifcation Insight - Exploratory Notebook*
#
# This notebook is part of the **MobileLens_2025** project. It performs Exploratory Data Analysis, hypothesis validation, feature engineering, and earlt modelling, following the structure defined in the project README:
#
# **Folder Strcuture**
#
# - **inputs/** = raw data ('movile_prices_2025.csv', 'phone_image.png')
# - **scripts/** = cleaning, EDA, modelling, dashboard builder
# - **notebooks/** = this notebook
# - **scripts/** = cleaned dataset, plots, model files
# - **dashboard/** = streamlit dashboard (multi-page)
# - **readme/** = project overview (README.md)

# %% [markdown]
# ---

# %% [markdown]
# # Import & Project Path

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly. express as px 

# set plot style 

sns.set(style="whitegrid")

# file paths 

RAW_DATA_PATH = "inputs/mobile_prices_2025.csv"
CLEANED_DATA_PATH = "outputs/cleaned_data"
PLOTS_PATH = "outputs/plots"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5 import plotly. express as px
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ---

# %% [markdown]
# # Load Dataset
# The raw dataset is stored in **inputs/mobile_prices_2025.csv**, following the project structure.
# This section loads the data for intial inspection.

# %%
df = pd.read_csv(RAW_DATA_PATH)
df.head()

# %% [markdown]
# ---

# %% [markdown]
# # Dataset Overview & Insight Checks
#
# Here I checked the shape, data types, missing values and basic statistical summaries. This aligns with the *Data Preparation* step in the README.

# %%
df.info()
df.describe().T
df.isna().sum()

# %% [markdown]
# ---

# %% [markdown]
# # Data Cleaning Preview
#
# The full cleanining pipeline lives in **scripts/clean_data,py**, this previews the cleaning steps here to undertand what needs to be standardised.
